# %% [markdown]
# # ML from DFT data

# %% [markdown]
# - [ ] learn on separated FM and NM AGAIN
# - [ ] remove high order BOP features before learing
# - [ ] Recursive Feature elimination after removing high order features
# - [ ] make recursion on bond energy
# - [ ] change OS to 1/10,
# - [ ] 1/10 OS and scf bop
# - learn form library features
# - compare different regression methods
#    - Linear regression
#    - add SVM
#    - kernel methods
#    - Gaussian process.
# - compare different test-train splittings
# - Learn on increasing domain knowledge

# %% [markdown]
#  - input: clean features dataframes from pickles
#  - output : plots and Models

# %%
from Tools.DatasetTools.Commoms import *

# %%
plt.rc('figure', figsize=(18, 8))
plt.rc('font', size=22)
from matplotlib.lines import Line2D

# %% [markdown]
# # Parameters

# %%
from Tools.DatasetTools.DatasetOperator import Dataset

# %%
DS = Dataset('Fe-Mo')

# %%
DS.BS
# Out:
#                                                                V        E0  \
# Fe_pv24.C36.FM                        bulk  C36.FM  12.049606 A  -8.109714
# Fe_pv29.chi.FM                        bulk  chi.FM  12.050793 A  -8.137048
# Fe_pv14Mo_sv10.C36-AABAB.FM     bulk  C36-AABAB.FM  14.643681 A  -8.883492
# Fe_pv22Mo_sv8.sigma-AAAAB.FM  bulk  sigma-AAAAB.FM  12.759638 A  -8.843901
# Fe_pv14Mo_sv10.C36-ABAAB.FM     bulk  C36-ABAAB.FM  13.931013 A  -9.081825
# ...                                            ...           ...       ...
# Fe_pv25Mo_sv4.chi-ABAA.NM           bulk  chi-ABAA  11.072302 A  -8.505552
# Fe_pv16Mo_sv8.C36-BBAAA.NM         bulk  C36-BBAAA  12.044661 A  -9.117739
# Fe_pv8Mo_sv4.C14-BAA.NM              bulk  C14-BAA  12.031891 A  -9.133101
# Fe_pv4.fcc-cubic.NM                bulk  fcc-cubic  10.248696 A  -8.104999
# Fe_pv2.hcp.NM                            bulk  hcp  10.193118 A  -8.184069
#
#                                             B                         fit  \
# Fe_pv24.C36.FM                150.452690 GPa   murnaghan  volume_relaxed
# Fe_pv29.chi.FM                152.259441 GPa   murnaghan  volume_relaxed
# Fe_pv14Mo_sv10.C36-AABAB.FM   154.045319 GPa   murnaghan  volume_relaxed
# Fe_pv22Mo_sv8.sigma-AAAAB.FM  158.862435 GPa   murnaghan  volume_relaxed
# Fe_pv14Mo_sv10.C36-ABAAB.FM   159.466599 GPa   murnaghan  volume_relaxed
# ...                                       ...                         ...
# Fe_pv25Mo_sv4.chi-ABAA.NM     279.868523 GPa   murnaghan  volume_relaxed
# Fe_pv16Mo_sv8.C36-BBAAA.NM    281.820517 GPa   murnaghan  volume_relaxed
# Fe_pv8Mo_sv4.C14-BAA.NM       282.397960 GPa   murnaghan  volume_relaxed
# Fe_pv4.fcc-cubic.NM           283.740438 GPa   murnaghan  volume_relaxed
# Fe_pv2.hcp.NM                 287.396036 GPa   murnaghan  volume_relaxed
#
#                                    xc encut deltak ncrash  nelem  ...  atom_B  \
# Fe_pv24.C36.FM                PBE-PAW   450  0.020      0      1  ...
# Fe_pv29.chi.FM                PBE-PAW   450  0.020      0      1  ...
# Fe_pv14Mo_sv10.C36-AABAB.FM   PBE-PAW   450  0.020      0      2  ...   Mo_sv
# Fe_pv22Mo_sv8.sigma-AAAAB.FM  PBE-PAW   450  0.020      0      2  ...   Mo_sv
# Fe_pv14Mo_sv10.C36-ABAAB.FM   PBE-PAW   450  0.020      0      2  ...   Mo_sv
# ...                               ...   ...    ...    ...    ...  ...     ...
# Fe_pv25Mo_sv4.chi-ABAA.NM     PBE-PAW   450  0.020      0      2  ...   Mo_sv
# Fe_pv16Mo_sv8.C36-BBAAA.NM    PBE-PAW   450  0.020      0      2  ...   Mo_sv
# Fe_pv8Mo_sv4.C14-BAA.NM       PBE-PAW   450  0.020      0      2  ...   Mo_sv
# Fe_pv4.fcc-cubic.NM           PBE-PAW   450  0.020      0      1  ...
# Fe_pv2.hcp.NM                 PBE-PAW   450  0.020      0      1  ...
#
#                               atom_C num_atom_A num_atom_B num_atom_C  \
# Fe_pv24.C36.FM                               24          0          0
# Fe_pv29.chi.FM                               29          0          0
# Fe_pv14Mo_sv10.C36-AABAB.FM                  14         10          0
# Fe_pv22Mo_sv8.sigma-AAAAB.FM                 22          8          0
# Fe_pv14Mo_sv10.C36-ABAAB.FM                  14         10          0
# ...                              ...        ...        ...        ...
# Fe_pv25Mo_sv4.chi-ABAA.NM                    25          4          0
# Fe_pv16Mo_sv8.C36-BBAAA.NM                   16          8          0
# Fe_pv8Mo_sv4.C14-BAA.NM                       8          4          0
# Fe_pv4.fcc-cubic.NM                           4          0          0
# Fe_pv2.hcp.NM                                 2          0          0
#
#                              num_atoms     Fe_pv     Mo_sv        EF  Phase
# Fe_pv24.C36.FM                    24.0  1.000000  0.000000   0.14558    C36
# Fe_pv29.chi.FM                    29.0  1.000000  0.000000  0.118246    chi
# Fe_pv14Mo_sv10.C36-AABAB.FM       24.0  0.583333  0.416667  0.488047    C36
# Fe_pv22Mo_sv8.sigma-AAAAB.FM      30.0  0.733333  0.266667   0.12579  sigma
# Fe_pv14Mo_sv10.C36-ABAAB.FM       24.0  0.583333  0.416667  0.289714    C36
# ...                                ...       ...       ...       ...    ...
# Fe_pv25Mo_sv4.chi-ABAA.NM         29.0  0.862069  0.137931  0.119258    chi
# Fe_pv16Mo_sv8.C36-BBAAA.NM        24.0  0.666667  0.333333  0.030551    C36
# Fe_pv8Mo_sv4.C14-BAA.NM           12.0  0.666667  0.333333  0.015189    C14
# Fe_pv4.fcc-cubic.NM                4.0  1.000000  0.000000  0.150295    fcc
# Fe_pv2.hcp.NM                      2.0  1.000000  0.000000  0.071225    hcp
#
# [273 rows x 23 columns]

# %% [markdown]
# # Targets

# %%
fig, ax = plt.subplots(1,3, figsize=(25, 5), sharey = True)
sns.histplot( DS.BS['B0'], ax= ax[0])
sns.histplot( DS.BS['EF'], ax= ax[1])
sns.histplot( DS.BS['V0'], ax= ax[2])
ax[0].set_xlabel('$B_0$')
ax[1].set_xlabel('$\Delta E_f$')
ax[2].set_xlabel('$V_0$')
# Out:
# Text(0.5, 0, '$V_0$')

# %% [markdown]
# # Machine Learning

# %%
from Tools.DatasetTools.MLConveniences import *

# %%
resultslocation = DS.resultslocation

# %% [markdown]
# ## Feature sets

# %%
Features = DS.Features  # {name: pd.read_pickle(filename) for name, filename in DescriptorFileList.items()}

# %%
Features['Canonical BOP']
# Out:
#                                  Structure  Mag      U_bind  \
# Fe_pv8Mo_sv22.sigma-BBABB.FM            10    0 -100.702297
# Fe_pv10Mo_sv20.sigma-ABBAB.FM           10    0  -78.594335
# Fe_pv4Mo_sv20.C36-ABBBB.FM               3    0  -94.449166
# Fe_pv5Mo_sv24.chi-AABB.FM                6    0 -116.205661
# Fe_pv15Mo_sv38.R-AAAABBBBBBB.NM          4    1 -121.105805
# ...                                    ...  ...         ...
# Fe_pv3Mo_sv10.mu-ABBBA.NM                9    1  -40.035290
# Fe_pv8Mo_sv22.sigma-BBABB.NM            10    1 -100.702297
# Fe_pv1Mo_sv3.L12-AB3.FM                  7    0  -12.617373
# Fe_pv8Mo_sv22.sigma-BBBBA.FM            10    0  -94.569986
# Fe_pv10Mo_sv20.sigma-ABBAB.NM           10    1  -78.594335
#
#                                  U_bond_atom_list_1_0  \
# Fe_pv8Mo_sv22.sigma-BBABB.FM                -7.906327
# Fe_pv10Mo_sv20.sigma-ABBAB.FM               -7.771059
# Fe_pv4Mo_sv20.C36-ABBBB.FM                  -8.534487
# Fe_pv5Mo_sv24.chi-AABB.FM                   -8.244366
# Fe_pv15Mo_sv38.R-AAAABBBBBBB.NM             -8.136275
# ...                                               ...
# Fe_pv3Mo_sv10.mu-ABBBA.NM                   -8.020136
# Fe_pv8Mo_sv22.sigma-BBABB.NM                -7.906327
# Fe_pv1Mo_sv3.L12-AB3.FM                     -6.832601
# Fe_pv8Mo_sv22.sigma-BBBBA.FM                -7.892530
# Fe_pv10Mo_sv20.sigma-ABBAB.NM               -7.771059
#
#                                  U_bond_atom_list_1_CN12  \
# Fe_pv8Mo_sv22.sigma-BBABB.FM                   -1.428383
# Fe_pv10Mo_sv20.sigma-ABBAB.FM                  -1.424594
# Fe_pv4Mo_sv20.C36-ABBBB.FM                     -7.595698
# Fe_pv5Mo_sv24.chi-AABB.FM                      -6.070495
# Fe_pv15Mo_sv38.R-AAAABBBBBBB.NM                -2.533063
# ...                                                  ...
# Fe_pv3Mo_sv10.mu-ABBBA.NM                      -2.520056
# Fe_pv8Mo_sv22.sigma-BBABB.NM                   -1.428383
# Fe_pv1Mo_sv3.L12-AB3.FM                        -6.832601
# Fe_pv8Mo_sv22.sigma-BBBBA.FM                   -5.305761
# Fe_pv10Mo_sv20.sigma-ABBAB.NM                  -1.424594
#
#                                  U_bond_atom_list_1_CN13  \
# Fe_pv8Mo_sv22.sigma-BBABB.FM                    0.000000
# Fe_pv10Mo_sv20.sigma-ABBAB.FM                   0.000000
# Fe_pv4Mo_sv20.C36-ABBBB.FM                      0.000000
# Fe_pv5Mo_sv24.chi-AABB.FM                      -1.652565
# Fe_pv15Mo_sv38.R-AAAABBBBBBB.NM                 0.000000
# ...                                                  ...
# Fe_pv3Mo_sv10.mu-ABBBA.NM                       0.000000
# Fe_pv8Mo_sv22.sigma-BBABB.NM                    0.000000
# Fe_pv1Mo_sv3.L12-AB3.FM                         0.000000
# Fe_pv8Mo_sv22.sigma-BBBBA.FM                    0.000000
# Fe_pv10Mo_sv20.sigma-ABBAB.NM                   0.000000
#
#                                  U_bond_atom_list_1_CN14  \
# Fe_pv8Mo_sv22.sigma-BBABB.FM                   -6.005237
# Fe_pv10Mo_sv20.sigma-ABBAB.FM                  -5.906606
# Fe_pv4Mo_sv20.C36-ABBBB.FM                      0.000000
# Fe_pv5Mo_sv24.chi-AABB.FM                       0.000000
# Fe_pv15Mo_sv38.R-AAAABBBBBBB.NM                -0.844603
# ...                                                  ...
# Fe_pv3Mo_sv10.mu-ABBBA.NM                      -0.663807
# Fe_pv8Mo_sv22.sigma-BBABB.NM                   -6.005237
# Fe_pv1Mo_sv3.L12-AB3.FM                         0.000000
# Fe_pv8Mo_sv22.sigma-BBBBA.FM                   -2.136368
# Fe_pv10Mo_sv20.sigma-ABBAB.NM                  -5.906606
#
#                                  U_bond_atom_list_1_CN15  \
# Fe_pv8Mo_sv22.sigma-BBABB.FM                   -0.472706
# Fe_pv10Mo_sv20.sigma-ABBAB.FM                  -0.439859
# Fe_pv4Mo_sv20.C36-ABBBB.FM                      0.000000
# Fe_pv5Mo_sv24.chi-AABB.FM                       0.000000
# Fe_pv15Mo_sv38.R-AAAABBBBBBB.NM                -0.318349
# ...                                                  ...
# Fe_pv3Mo_sv10.mu-ABBBA.NM                      -0.397166
# Fe_pv8Mo_sv22.sigma-BBABB.NM                   -0.472706
# Fe_pv1Mo_sv3.L12-AB3.FM                         0.000000
# Fe_pv8Mo_sv22.sigma-BBBBA.FM                   -0.450401
# Fe_pv10Mo_sv20.sigma-ABBAB.NM                  -0.439859
#
#                                  U_bond_atom_list_1_CN16  moments_1_0  ...  \
# Fe_pv8Mo_sv22.sigma-BBABB.FM                    0.000000     1.174563  ...
# Fe_pv10Mo_sv20.sigma-ABBAB.FM                   0.000000     1.201761  ...
# Fe_pv4Mo_sv20.C36-ABBBB.FM                     -0.938789     1.303069  ...
# Fe_pv5Mo_sv24.chi-AABB.FM                      -0.521305     1.162619  ...
# Fe_pv15Mo_sv38.R-AAAABBBBBBB.NM                -4.440260     1.218738  ...
# ...                                                  ...          ...  ...
# Fe_pv3Mo_sv10.mu-ABBBA.NM                      -4.439107     1.265062  ...
# Fe_pv8Mo_sv22.sigma-BBABB.NM                    0.000000     1.174563  ...
# Fe_pv1Mo_sv3.L12-AB3.FM                         0.000000     1.063750  ...
# Fe_pv8Mo_sv22.sigma-BBBBA.FM                    0.000000     1.174563  ...
# Fe_pv10Mo_sv20.sigma-ABBAB.NM                   0.000000     1.201761  ...
#
#                                  Binf_1_CN13  Binf_1_CN14  Binf_1_CN15  \
# Fe_pv8Mo_sv22.sigma-BBABB.FM        0.000000     0.660966     0.164368
# Fe_pv10Mo_sv20.sigma-ABBAB.FM       0.000000     0.668575     0.166260
# Fe_pv4Mo_sv20.C36-ABBBB.FM          0.000000     0.000000     0.000000
# Fe_pv5Mo_sv24.chi-AABB.FM           0.451346     0.000000     0.000000
# Fe_pv15Mo_sv38.R-AAAABBBBBBB.NM     0.000000     0.256809     0.124851
# ...                                      ...          ...          ...
# Fe_pv3Mo_sv10.mu-ABBBA.NM           0.000000     0.220371     0.224323
# Fe_pv8Mo_sv22.sigma-BBABB.NM        0.000000     0.660966     0.164368
# Fe_pv1Mo_sv3.L12-AB3.FM             0.000000     0.000000     0.000000
# Fe_pv8Mo_sv22.sigma-BBBBA.FM        0.000000     0.660966     0.164368
# Fe_pv10Mo_sv20.sigma-ABBAB.NM       0.000000     0.668575     0.166260
#
#                                  Binf_1_CN16      sf_0   sf_CN12   sf_CN13  \
# Fe_pv8Mo_sv22.sigma-BBABB.FM        0.000000  1.224171  1.311938  0.000000
# Fe_pv10Mo_sv20.sigma-ABBAB.FM       0.000000  1.224174  1.311938  0.000000
# Fe_pv4Mo_sv20.C36-ABBBB.FM          0.501537  1.081732  1.156282  0.000000
# Fe_pv5Mo_sv24.chi-AABB.FM           0.186186  1.251703  1.437268  1.179083
# Fe_pv15Mo_sv38.R-AAAABBBBBBB.NM     0.170809  1.192249  1.343509  0.000000
# ...                                      ...       ...       ...       ...
# Fe_pv3Mo_sv10.mu-ABBBA.NM           0.222761  1.071111  1.222567  0.000000
# Fe_pv8Mo_sv22.sigma-BBABB.NM        0.000000  1.224171  1.311938  0.000000
# Fe_pv1Mo_sv3.L12-AB3.FM             0.000000  1.140024  1.140024  0.000000
# Fe_pv8Mo_sv22.sigma-BBBBA.FM        0.000000  1.224171  1.311938  0.000000
# Fe_pv10Mo_sv20.sigma-ABBAB.NM       0.000000  1.224174  1.311938  0.000000
#
#                                   sf_CN14   sf_CN15   sf_CN16
# Fe_pv8Mo_sv22.sigma-BBABB.FM     1.187302  1.155462  0.000000
# Fe_pv10Mo_sv20.sigma-ABBAB.FM    1.187308  1.155463  0.000000
# Fe_pv4Mo_sv20.C36-ABBBB.FM       0.000000  0.000000  0.901327
# Fe_pv5Mo_sv24.chi-AABB.FM        0.000000  0.000000  1.006205
# Fe_pv15Mo_sv38.R-AAAABBBBBBB.NM  1.139857  0.956735  0.947607
# ...                                   ...       ...       ...
# Fe_pv3Mo_sv10.mu-ABBBA.NM        0.902499  0.748344  1.001884
# Fe_pv8Mo_sv22.sigma-BBABB.NM     1.187302  1.155462  0.000000
# Fe_pv1Mo_sv3.L12-AB3.FM          0.000000  0.000000  0.000000
# Fe_pv8Mo_sv22.sigma-BBBBA.FM     1.187302  1.155462  0.000000
# Fe_pv10Mo_sv20.sigma-ABBAB.NM    1.187308  1.155463  0.000000
#
# [254 rows x 392 columns]

# %%
Features.keys()
# Out:
# dict_keys(['atomic', 'dataset', 'Pyscal', 'Canonical BOP', 'Projections BOP', 'Projections OS BOP', 'Projections sOS BOP', 'dataset + Canonical BOP', 'dataset + Projections BOP', 'dataset + Projections OS BOP', 'dataset + Projections sOS BOP'])

# %% [markdown]
# ## BOP features with and without CP averages

# %%
def clean_CNAVS(name:str, features:pd.core.frame.DataFrame):
    if 'BOP' in name:
        return features.filter(regex='^(?!.*_CN)')
    else:
        return features

# %%
def clean_zeros(name:str, features:pd.core.frame.DataFrame):
    if 'BOP' in name:
        return features.filter(regex='^(?!.*_0$)')
    else:
        return features

# %%
def notyetclean(name:str):
    return ('BOP' in name) and ('CNAV' not in name) and ('Zeros' not in name)

# %%
# Features.update({name+' no CNAV': clean_CNAVS(name, features) for name, features in Features.items() if notyetclean(name) } )

# %%
# Features.update({name+' no Zeros': clean_zeros(name, features) for name, features in Features.items() if notyetclean(name)} )

# %% [markdown]
# ## test - train splits

# %%
samplesplit = DS.get_samplesplit(split_random_state=200)

# %% [markdown]
# # Models: adjust params

# %%
Models = {
    'SVR': Pipeline([('scaler', StandardScaler()), ('regressor', SVR())]),
}

# %%
Parameters = {
    'SVR': {'regressor__kernel':['linear', 'poly', 'rbf', 'sigmoid'],
            'regressor__degree':[2,3,4,5],
            'regressor__coef0': [0.0,0.5,1,2],
           }
}

# %%
samplefolds = list(DS.get_folds())

# %% [markdown]
# # fits

# %%
FittedModels = {}

# %%
Models
# Out:
# {'SVR': Pipeline(steps=[('scaler', StandardScaler()), ('regressor', SVR())])}

# %%
for name, model in Models.items():
    print (name)
    progress = tqdm(Features.items())
    for key, features in progress: #Features.items():
        model = GridSearchCV(
            Models[name],
            Parameters[name], 
            scoring='neg_root_mean_squared_error', 
            cv = samplefolds,
            verbose = 1,
            return_train_score= True,
        )
        FittedModels[(name, key)] = model.fit(features, DS.target)
# Out:
# SVR
#   0%|          | 0/11 [00:00<?, ?it/s]
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# Fitting 5 folds for each of 64 candidates, totalling 320 fits

# %%
best_scores = {}
for (modelname, featurename), fittedmodel in FittedModels.items():
    best_scores[(modelname, featurename)] = {'test': abs(fittedmodel.best_score_)}
best_scores = pd.DataFrame.from_dict(best_scores, orient='index')
best_scores.index = pd.MultiIndex.from_tuples(best_scores.index)
best_scores.sort_values(by='test', ascending=True, inplace=True)
best_scores.sort_index(level=0, sort_remaining=False, ascending=True, inplace=True)

# %%
best_combi = best_scores.idxmin()['test']

# %%
best_combi
# Out:
# ('SVR', 'Projections sOS BOP')

# %%
results = pd.DataFrame.from_dict(FittedModels[best_combi].cv_results_)

# %%
results.sort_values(by='mean_test_score', ascending=False, inplace=True)

# %%
for parameters in Parameters.values():
    for key in parameters.keys():
        print (results.groupby(by='param_'+key)['mean_test_score'].max())
# Out:
# param_regressor__kernel
# linear    -0.065527
# poly      -0.071150
# rbf       -0.080754
# sigmoid   -0.521705
# Name: mean_test_score, dtype: float64
# param_regressor__degree
# 2   -0.065527
# 3   -0.065527
# 4   -0.065527
# 5   -0.065527
# Name: mean_test_score, dtype: float64
# param_regressor__coef0
# 0.0   -0.065527
# 0.5   -0.065527
# 1.0   -0.065527
# 2.0   -0.065527
# Name: mean_test_score, dtype: float64

# %%
ax = best_scores.unstack(level=0).sort_values(by=('test','SVR')).plot.bar()
ax.set_ylim([0,0.1])
# Out:
# (0.0, 0.1)

# %%
FittedModels[best_combi].best_params_
# Out:
# {'regressor__coef0': 0.0,
#  'regressor__degree': 2,
#  'regressor__kernel': 'linear'}
