# %%
import pandas as pd

# %%
atoms = pd.read_pickle('CrCoW-sorted-POSCAR-initial-rescaled-AtomsObjects.pkl')

# %%
for index, atom in atoms.atoms.iteritems():
    print(pd.Series([atom], index = [index]).values[0])
# Out:
# Atoms(symbols='Co6W6', pbc=True, cell=[[2.2140135370609073, -3.8347821468663446, 0.0], [2.2140135370609073, 3.8347821468663446, 0.0], [0.0, 0.0, 7.283165795190671]])
# Atoms(symbols='Co6W6', pbc=True, cell=[[2.2140135370609073, -3.8347821468663446, 0.0], [2.2140135370609073, 3.8347821468663446, 0.0], [0.0, 0.0, 7.283165795190671]])
# Atoms(symbols='Cr6W2', pbc=True, cell=[[5.051294687125865, 0.0, 0.0], [-2.5256473435629325, 4.374547481418178, 0.0], [0.0, 0.0, 4.053749858428188]])
# Atoms(symbols='Cr6W2', pbc=True, cell=[[5.051294687125865, 0.0, 0.0], [-2.5256473435629325, 4.374547481418178, 0.0], [0.0, 0.0, 4.053749858428188]])
# Atoms(symbols='Cr16Co4W10', pbc=True, cell=[8.577749708330101, 8.577749708330101, 4.4604298483316525])
# Atoms(symbols='Co10W14', pbc=True, cell=[[2.215848137238236, -3.837959766103487, 0.0], [2.215848137238236, 3.837959766103487, 0.0], [0.0, 0.0, 14.54222133542239]])
# ...
