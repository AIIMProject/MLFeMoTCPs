# %%
import re
import pandas as pd

import glob
from itertools import product

from IPython.display import display, Markdown, Latex

# %%
def collect(filename,struclist):
    briefsummary=open(filename,'r')
    Lines = briefsummary.readlines() 
    output = []
    for struc in struclist:
        found = False
        for line in Lines: 
            if (struc+' ') in line:
                found = True
                entries = line.split()
                energy = entries[6]
                output.append(struc + "+++++++++")  #" + energy)
                break
        if not(found):
             output.append(struc + "  ---------")  
    return output

# %%
unaryFM  =['fcc','hcp','bcc','A15','C14','C15','C36','sigma','mu','chi']
binaryfccFM  =['L10-NiAl-AB.FM', 'L12-A3B.FM', 'L12-AB3.FM']
binarybccFM  =['B2-AB.FM', 'B32-AB.FM', 'D03-A3B.FM', 'D03-AB3.FM']
binaryhcpFM  =['D0_19-A3B.FM', 'D0_19-AB3.FM', 'hcp-AB.FM']
binaryA15FM  =['A15-AB.FM', 'A15-BA.FM']
binaryC14FM  =['C14-AAB.FM', 'C14-ABA.FM', 'C14-ABB.FM', 'C14-BAA.FM', 'C14-BAB.FM', 'C14-BBA.FM']
binaryC15FM  =['C15-AB2.FM', 'C15-A2B.FM' ]
binaryC36FM  =['C36-AAAAB.FM', 'C36-AAABA.FM', 'C36-AAABB.FM', 'C36-AABAA.FM', 'C36-AABAB.FM',
               'C36-AABBA.FM', 'C36-AABBB.FM', 'C36-ABAAA.FM', 'C36-ABAAB.FM', 'C36-ABABA.FM',
               'C36-ABABB.FM', 'C36-ABBAA.FM', 'C36-ABBAB.FM', 'C36-ABBBA.FM', 'C36-ABBBB.FM',
               'C36-BAAAA.FM', 'C36-BAAAB.FM', 'C36-BAABA.FM', 'C36-BAABB.FM', 'C36-BABAA.FM',
               'C36-BABAB.FM', 'C36-BABBA.FM', 'C36-BABBB.FM', 'C36-BBAAA.FM', 'C36-BBAAB.FM',
               'C36-BBABA.FM', 'C36-BBABB.FM', 'C36-BBBAA.FM', 'C36-BBBAB.FM', 'C36-BBBBA.FM']
binarysigmaFM=['sigma-AAAAB.FM', 'sigma-AAABA.FM', 'sigma-AAABB.FM', 'sigma-AABAA.FM', 'sigma-AABAB.FM',
               'sigma-AABBA.FM', 'sigma-AABBB.FM', 'sigma-ABAAA.FM', 'sigma-ABAAB.FM', 'sigma-ABABA.FM',
               'sigma-ABABB.FM', 'sigma-ABBAA.FM', 'sigma-ABBAB.FM', 'sigma-ABBBA.FM', 'sigma-ABBBB.FM',
               'sigma-BAAAA.FM', 'sigma-BAAAB.FM', 'sigma-BAABA.FM', 'sigma-BAABB.FM', 'sigma-BABAA.FM',
               'sigma-BABAB.FM', 'sigma-BABBA.FM', 'sigma-BABBB.FM', 'sigma-BBAAA.FM', 'sigma-BBAAB.FM',
               'sigma-BBABA.FM', 'sigma-BBABB.FM', 'sigma-BBBAA.FM', 'sigma-BBBAB.FM', 'sigma-BBBBA.FM']
binarymuFM   =['mu-AAAAB.FM', 'mu-AABAA.FM', 'mu-AABBB.FM', 'mu-ABABA.FM', 'mu-ABBAB.FM', 'mu-BAAAA.FM', 
               'mu-BAABB.FM', 'mu-BABBA.FM', 'mu-BBAAB.FM', 'mu-BBBAA.FM', 'mu-AAABA.FM', 'mu-AABAB.FM',
               'mu-ABAAA.FM', 'mu-ABABB.FM', 'mu-ABBBA.FM', 'mu-BAAAB.FM', 'mu-BABAA.FM', 'mu-BABBB.FM',
               'mu-BBABA.FM', 'mu-BBBAB.FM', 'mu-AAABB.FM', 'mu-AABBA.FM', 'mu-ABAAB.FM', 'mu-ABBAA.FM',
               'mu-ABBBB.FM', 'mu-BAABA.FM', 'mu-BABAB.FM', 'mu-BBAAA.FM', 'mu-BBABB.FM', 'mu-BBBBA.FM']
binarychiFM  =['chi-AAAB.FM', 'chi-AABB.FM', 'chi-ABAB.FM', 'chi-ABBB.FM', 'chi-BAAB.FM', 'chi-BABB.FM',
               'chi-BBAB.FM', 'chi-AABA.FM', 'chi-ABAA.FM', 'chi-ABBA.FM', 'chi-BAAA.FM', 'chi-BABA.FM',
               'chi-BBAA.FM', 'chi-BBBA.FM']
list_binary_mag = binaryA15FM+binaryC14FM+binaryC15FM+binaryC36FM+binarysigmaFM+binarymuFM+binarychiFM

# %%
unary  =['fcc','hcp','bcc','A15','C14','C15','C36','sigma','mu','chi']
binaryfcc  =['L10-NiAl-AB', 'L12-A3B', 'L12-AB3']
binarybcc  =['B2-AB', 'B32-AB', 'D03-A3B', 'D03-AB3']
binaryhcp  =['D0_19-A3B', 'D0_19-AB3', 'hcp-AB']
binaryA15  =['A15-AB', 'A15-BA']
binaryC14  =['C14-AAB', 'C14-ABA', 'C14-ABB', 'C14-BAA', 'C14-BAB', 'C14-BBA']
binaryC15  =['C15-AB2', 'C15-A2B' ]
binaryC36  =['C36-AAAAB', 'C36-AAABA', 'C36-AAABB', 'C36-AABAA', 'C36-AABAB',
             'C36-AABBA', 'C36-AABBB', 'C36-ABAAA', 'C36-ABAAB', 'C36-ABABA',
             'C36-ABABB', 'C36-ABBAA', 'C36-ABBAB', 'C36-ABBBA', 'C36-ABBBB',
             'C36-BAAAA', 'C36-BAAAB', 'C36-BAABA', 'C36-BAABB', 'C36-BABAA',
             'C36-BABAB', 'C36-BABBA', 'C36-BABBB', 'C36-BBAAA', 'C36-BBAAB',
             'C36-BBABA', 'C36-BBABB', 'C36-BBBAA', 'C36-BBBAB', 'C36-BBBBA']
binarysigma=['sigma-AAAAB', 'sigma-AAABA', 'sigma-AAABB', 'sigma-AABAA', 'sigma-AABAB',
             'sigma-AABBA', 'sigma-AABBB', 'sigma-ABAAA', 'sigma-ABAAB', 'sigma-ABABA',
             'sigma-ABABB', 'sigma-ABBAA', 'sigma-ABBAB', 'sigma-ABBBA', 'sigma-ABBBB',
             'sigma-BAAAA', 'sigma-BAAAB', 'sigma-BAABA', 'sigma-BAABB', 'sigma-BABAA',
             'sigma-BABAB', 'sigma-BABBA', 'sigma-BABBB', 'sigma-BBAAA', 'sigma-BBAAB',
             'sigma-BBABA', 'sigma-BBABB', 'sigma-BBBAA', 'sigma-BBBAB', 'sigma-BBBBA']
binarymu   =['mu-AAAAB', 'mu-AABAA', 'mu-AABBB', 'mu-ABABA', 'mu-ABBAB', 'mu-BAAAA', 
             'mu-BAABB', 'mu-BABBA', 'mu-BBAAB', 'mu-BBBAA', 'mu-AAABA', 'mu-AABAB',
             'mu-ABAAA', 'mu-ABABB', 'mu-ABBBA', 'mu-BAAAB', 'mu-BABAA', 'mu-BABBB',
             'mu-BBABA', 'mu-BBBAB', 'mu-AAABB', 'mu-AABBA', 'mu-ABAAB', 'mu-ABBAA',
             'mu-ABBBB', 'mu-BAABA', 'mu-BABAB', 'mu-BBAAA', 'mu-BBABB', 'mu-BBBBA']
binarychi  =['chi-AAAB', 'chi-AABB', 'chi-ABAB', 'chi-ABBB', 'chi-BAAB', 'chi-BABB',
             'chi-BBAB', 'chi-AABA', 'chi-ABAA', 'chi-ABBA', 'chi-BAAA', 'chi-BABA',
             'chi-BBAA', 'chi-BBBA']
list_binary_nonmag = binaryA15+binaryC14+binaryC15+binaryC36+binarysigma+binarymu+binarychi

# %%
ternaryA15FM = ['A15-AAAAAABC.FM', 'A15-AAAAABCC.FM', 'A15-AAAAACBB.FM', 'A15-AAAABACC.FM',
                'A15-AAAACABB.FM', 'A15-AAABAACC.FM', 'A15-AAACAABB.FM', 'A15-AABAAACC.FM',
                'A15-AACAAABB.FM', 'A15-ABAAAACC.FM', 'A15-ACAAAABB.FM', 'A15-BAAAAACC.FM',
                'A15-CAAAAABB.FM']
ternaryC14FM = ['C14-ABC.FM', 'C14-ACB.FM', 'C14-BAC.FM', 'C14-BCA.FM', 'C14-CAB.FM', 
                'C14-CBA.FM']
ternaryC15FM = []
ternaryC36FM   = ['C36-AAABC.FM', 'C36-AAACB.FM', 'C36-AABAC.FM', 'C36-AABBC.FM', 'C36-AABCA.FM', 'C36-AABCB.FM',
                  'C36-AABCC.FM', 'C36-AACAB.FM', 'C36-AACBA.FM', 'C36-AACBB.FM', 'C36-AACBC.FM', 'C36-AACCB.FM',
                  'C36-ABAAC.FM', 'C36-ABABC.FM', 'C36-ABACA.FM', 'C36-ABACB.FM', 'C36-ABACC.FM', 'C36-ABBAC.FM',
                  'C36-ABBBC.FM', 'C36-ABBCA.FM', 'C36-ABBCB.FM', 'C36-ABBCC.FM', 'C36-ABCAA.FM', 'C36-ABCAB.FM',
                  'C36-ABCAC.FM', 'C36-ABCBA.FM', 'C36-ABCBB.FM', 'C36-ABCBC.FM', 'C36-ABCCA.FM', 'C36-ABCCB.FM',
                  'C36-ABCCC.FM', 'C36-ACAAB.FM', 'C36-ACABA.FM', 'C36-ACABB.FM', 'C36-ACABC.FM', 'C36-ACACB.FM',
                  'C36-ACBAA.FM', 'C36-ACBAB.FM', 'C36-ACBAC.FM', 'C36-ACBBA.FM', 'C36-ACBBB.FM', 'C36-ACBBC.FM',
                  'C36-ACBCA.FM', 'C36-ACBCB.FM', 'C36-ACBCC.FM', 'C36-ACCAB.FM', 'C36-ACCBA.FM', 'C36-ACCBB.FM',
                  'C36-ACCBC.FM', 'C36-ACCCB.FM', 'C36-BAAAC.FM', 'C36-BAABC.FM', 'C36-BAACA.FM', 'C36-BAACB.FM',
                  'C36-BAACC.FM', 'C36-BABAC.FM', 'C36-BABBC.FM', 'C36-BABCA.FM', 'C36-BABCB.FM', 'C36-BABCC.FM',
                  'C36-BACAA.FM', 'C36-BACAB.FM', 'C36-BACAC.FM', 'C36-BACBA.FM', 'C36-BACBB.FM', 'C36-BACBC.FM',
                  'C36-BACCA.FM', 'C36-BACCB.FM', 'C36-BACCC.FM', 'C36-BBAAC.FM', 'C36-BBABC.FM', 'C36-BBACA.FM',
                  'C36-BBACB.FM', 'C36-BBACC.FM', 'C36-BBBAC.FM', 'C36-BBBCA.FM', 'C36-BBCAA.FM', 'C36-BBCAB.FM',
                  'C36-BBCAC.FM', 'C36-BBCBA.FM', 'C36-BBCCA.FM', 'C36-BCAAA.FM', 'C36-BCAAB.FM', 'C36-BCAAC.FM',
                  'C36-BCABA.FM', 'C36-BCABB.FM', 'C36-BCABC.FM', 'C36-BCACA.FM', 'C36-BCACB.FM', 'C36-BCACC.FM',
                  'C36-BCBAA.FM', 'C36-BCBAB.FM', 'C36-BCBAC.FM', 'C36-BCBBA.FM', 'C36-BCBCA.FM', 'C36-BCCAA.FM',
                  'C36-BCCAB.FM', 'C36-BCCAC.FM', 'C36-BCCBA.FM', 'C36-BCCCA.FM', 'C36-CAAAB.FM', 'C36-CAABA.FM',
                  'C36-CAABB.FM', 'C36-CAABC.FM', 'C36-CAACB.FM', 'C36-CABAA.FM', 'C36-CABAB.FM', 'C36-CABAC.FM',
                  'C36-CABBA.FM', 'C36-CABBB.FM', 'C36-CABBC.FM', 'C36-CABCA.FM', 'C36-CABCB.FM', 'C36-CABCC.FM',
                  'C36-CACAB.FM', 'C36-CACBA.FM', 'C36-CACBB.FM', 'C36-CACBC.FM', 'C36-CACCB.FM', 'C36-CBAAA.FM',
                  'C36-CBAAB.FM', 'C36-CBAAC.FM', 'C36-CBABA.FM', 'C36-CBABB.FM', 'C36-CBABC.FM', 'C36-CBACA.FM',
                  'C36-CBACB.FM', 'C36-CBACC.FM', 'C36-CBBAA.FM', 'C36-CBBAB.FM', 'C36-CBBAC.FM', 'C36-CBBBA.FM',
                  'C36-CBBCA.FM', 'C36-CBCAA.FM', 'C36-CBCAB.FM', 'C36-CBCAC.FM', 'C36-CBCBA.FM', 'C36-CBCCA.FM',
                  'C36-CCAAB.FM', 'C36-CCABA.FM', 'C36-CCABB.FM', 'C36-CCABC.FM', 'C36-CCACB.FM', 'C36-CCBAA.FM',
                  'C36-CCBAB.FM', 'C36-CCBAC.FM', 'C36-CCBBA.FM', 'C36-CCBCA.FM', 'C36-CCCAB.FM', 'C36-CCCBA.FM']
ternarysigmaFM = ['sigma-AAABC.FM', 'sigma-AAACB.FM', 'sigma-AABAC.FM', 'sigma-AABBC.FM', 'sigma-AABCA.FM',
                  'sigma-AABCB.FM', 'sigma-AABCC.FM', 'sigma-AACAB.FM', 'sigma-AACBA.FM', 'sigma-AACBB.FM',
                  'sigma-AACBC.FM', 'sigma-AACCB.FM', 'sigma-ABAAC.FM', 'sigma-ABABC.FM', 'sigma-ABACA.FM',
                  'sigma-ABACB.FM', 'sigma-ABACC.FM', 'sigma-ABBAC.FM', 'sigma-ABBBC.FM', 'sigma-ABBCA.FM',
                  'sigma-ABBCB.FM', 'sigma-ABBCC.FM', 'sigma-ABCAA.FM', 'sigma-ABCAB.FM', 'sigma-ABCAC.FM',
                  'sigma-ABCBA.FM', 'sigma-ABCBB.FM', 'sigma-ABCBC.FM', 'sigma-ABCCA.FM', 'sigma-ABCCB.FM',
                  'sigma-ABCCC.FM', 'sigma-ACAAB.FM', 'sigma-ACABA.FM', 'sigma-ACABB.FM', 'sigma-ACABC.FM',
                  'sigma-ACACB.FM', 'sigma-ACBAA.FM', 'sigma-ACBAB.FM', 'sigma-ACBAC.FM', 'sigma-ACBBA.FM',
                  'sigma-ACBBB.FM', 'sigma-ACBBC.FM', 'sigma-ACBCA.FM', 'sigma-ACBCB.FM', 'sigma-ACBCC.FM',
                  'sigma-ACCAB.FM', 'sigma-ACCBA.FM', 'sigma-ACCBB.FM', 'sigma-ACCBC.FM', 'sigma-ACCCB.FM',
                  'sigma-BAAAC.FM', 'sigma-BAABC.FM', 'sigma-BAACA.FM', 'sigma-BAACB.FM', 'sigma-BAACC.FM',
                  'sigma-BABAC.FM', 'sigma-BABBC.FM', 'sigma-BABCA.FM', 'sigma-BABCB.FM', 'sigma-BABCC.FM',
                  'sigma-BACAA.FM', 'sigma-BACAB.FM', 'sigma-BACAC.FM', 'sigma-BACBA.FM', 'sigma-BACBB.FM',
                  'sigma-BACBC.FM', 'sigma-BACCA.FM', 'sigma-BACCB.FM', 'sigma-BACCC.FM', 'sigma-BBAAC.FM',
                  'sigma-BBABC.FM', 'sigma-BBACA.FM', 'sigma-BBACB.FM', 'sigma-BBACC.FM', 'sigma-BBBAC.FM',
                  'sigma-BBBCA.FM', 'sigma-BBCAA.FM', 'sigma-BBCAB.FM', 'sigma-BBCAC.FM', 'sigma-BBCBA.FM',
                  'sigma-BBCCA.FM', 'sigma-BCAAA.FM', 'sigma-BCAAB.FM', 'sigma-BCAAC.FM', 'sigma-BCABA.FM',
                  'sigma-BCABB.FM', 'sigma-BCABC.FM', 'sigma-BCACA.FM', 'sigma-BCACB.FM', 'sigma-BCACC.FM',
                  'sigma-BCBAA.FM', 'sigma-BCBAB.FM', 'sigma-BCBAC.FM', 'sigma-BCBBA.FM', 'sigma-BCBCA.FM',
                  'sigma-BCCAA.FM', 'sigma-BCCAB.FM', 'sigma-BCCAC.FM', 'sigma-BCCBA.FM', 'sigma-BCCCA.FM',
                  'sigma-CAAAB.FM', 'sigma-CAABA.FM', 'sigma-CAABB.FM', 'sigma-CAABC.FM', 'sigma-CAACB.FM',
                  'sigma-CABAA.FM', 'sigma-CABAB.FM', 'sigma-CABAC.FM', 'sigma-CABBA.FM', 'sigma-CABBB.FM',
                  'sigma-CABBC.FM', 'sigma-CABCA.FM', 'sigma-CABCB.FM', 'sigma-CABCC.FM', 'sigma-CACAB.FM',
                  'sigma-CACBA.FM', 'sigma-CACBB.FM', 'sigma-CACBC.FM', 'sigma-CACCB.FM', 'sigma-CBAAA.FM',
                  'sigma-CBAAB.FM', 'sigma-CBAAC.FM', 'sigma-CBABA.FM', 'sigma-CBABB.FM', 'sigma-CBABC.FM',
                  'sigma-CBACA.FM', 'sigma-CBACB.FM', 'sigma-CBACC.FM', 'sigma-CBBAA.FM', 'sigma-CBBAB.FM',
                  'sigma-CBBAC.FM', 'sigma-CBBBA.FM', 'sigma-CBBCA.FM', 'sigma-CBCAA.FM', 'sigma-CBCAB.FM',
                  'sigma-CBCAC.FM', 'sigma-CBCBA.FM', 'sigma-CBCCA.FM', 'sigma-CCAAB.FM', 'sigma-CCABA.FM',
                  'sigma-CCABB.FM', 'sigma-CCABC.FM', 'sigma-CCACB.FM', 'sigma-CCBAA.FM', 'sigma-CCBAB.FM',
                  'sigma-CCBAC.FM', 'sigma-CCBBA.FM', 'sigma-CCBCA.FM', 'sigma-CCCAB.FM', 'sigma-CCCBA.FM']
ternarymuFM    = ['mu-AAABC.FM', 'mu-AAACB.FM', 'mu-AABAC.FM', 'mu-AABBC.FM', 'mu-AABCA.FM', 'mu-AABCB.FM',
                  'mu-AABCC.FM', 'mu-AACAB.FM', 'mu-AACBA.FM', 'mu-AACBB.FM', 'mu-AACBC.FM', 'mu-AACCB.FM',
                  'mu-ABAAC.FM', 'mu-ABABC.FM', 'mu-ABACA.FM', 'mu-ABACB.FM', 'mu-ABACC.FM', 'mu-ABBAC.FM',
                  'mu-ABBBC.FM', 'mu-ABBCA.FM', 'mu-ABBCB.FM', 'mu-ABBCC.FM', 'mu-ABCAA.FM', 'mu-ABCAB.FM',
                  'mu-ABCAC.FM', 'mu-ABCBA.FM', 'mu-ABCBB.FM', 'mu-ABCBC.FM', 'mu-ABCCA.FM', 'mu-ABCCB.FM',
                  'mu-ABCCC.FM', 'mu-ACAAB.FM', 'mu-ACABA.FM', 'mu-ACABB.FM', 'mu-ACABC.FM', 'mu-ACACB.FM',
                  'mu-ACBAA.FM', 'mu-ACBAB.FM', 'mu-ACBAC.FM', 'mu-ACBBA.FM', 'mu-ACBBB.FM', 'mu-ACBBC.FM',
                  'mu-ACBCA.FM', 'mu-ACBCB.FM', 'mu-ACBCC.FM', 'mu-ACCAB.FM', 'mu-ACCBA.FM', 'mu-ACCBB.FM',
                  'mu-ACCBC.FM', 'mu-ACCCB.FM', 'mu-BAAAC.FM', 'mu-BAABC.FM', 'mu-BAACA.FM', 'mu-BAACB.FM',
                  'mu-BAACC.FM', 'mu-BABAC.FM', 'mu-BABBC.FM', 'mu-BABCA.FM', 'mu-BABCB.FM', 'mu-BABCC.FM',
                  'mu-BACAA.FM', 'mu-BACAB.FM', 'mu-BACAC.FM', 'mu-BACBA.FM', 'mu-BACBB.FM', 'mu-BACBC.FM',
                  'mu-BACCA.FM', 'mu-BACCB.FM', 'mu-BACCC.FM', 'mu-BBAAC.FM', 'mu-BBABC.FM', 'mu-BBACA.FM',
                  'mu-BBACB.FM', 'mu-BBACC.FM', 'mu-BBBAC.FM', 'mu-BBBCA.FM', 'mu-BBCAA.FM', 'mu-BBCAB.FM',
                  'mu-BBCAC.FM', 'mu-BBCBA.FM', 'mu-BBCCA.FM', 'mu-BCAAA.FM', 'mu-BCAAB.FM', 'mu-BCAAC.FM',
                  'mu-BCABA.FM', 'mu-BCABB.FM', 'mu-BCABC.FM', 'mu-BCACA.FM', 'mu-BCACB.FM', 'mu-BCACC.FM',
                  'mu-BCBAA.FM', 'mu-BCBAB.FM', 'mu-BCBAC.FM', 'mu-BCBBA.FM', 'mu-BCBCA.FM', 'mu-BCCAA.FM',
                  'mu-BCCAB.FM', 'mu-BCCAC.FM', 'mu-BCCBA.FM', 'mu-BCCCA.FM', 'mu-CAAAB.FM', 'mu-CAABA.FM',
                  'mu-CAABB.FM', 'mu-CAABC.FM', 'mu-CAACB.FM', 'mu-CABAA.FM', 'mu-CABAB.FM', 'mu-CABAC.FM',
                  'mu-CABBA.FM', 'mu-CABBB.FM', 'mu-CABBC.FM', 'mu-CABCA.FM', 'mu-CABCB.FM', 'mu-CABCC.FM',
                  'mu-CACAB.FM', 'mu-CACBA.FM', 'mu-CACBB.FM', 'mu-CACBC.FM', 'mu-CACCB.FM', 'mu-CBAAA.FM',
                  'mu-CBAAB.FM', 'mu-CBAAC.FM', 'mu-CBABA.FM', 'mu-CBABB.FM', 'mu-CBABC.FM', 'mu-CBACA.FM',
                  'mu-CBACB.FM', 'mu-CBACC.FM', 'mu-CBBAA.FM', 'mu-CBBAB.FM', 'mu-CBBAC.FM', 'mu-CBBBA.FM',
                  'mu-CBBCA.FM', 'mu-CBCAA.FM', 'mu-CBCAB.FM', 'mu-CBCAC.FM', 'mu-CBCBA.FM', 'mu-CBCCA.FM',
                  'mu-CCAAB.FM', 'mu-CCABA.FM', 'mu-CCABB.FM', 'mu-CCABC.FM', 'mu-CCACB.FM', 'mu-CCBAA.FM',
                  'mu-CCBAB.FM', 'mu-CCBAC.FM', 'mu-CCBBA.FM', 'mu-CCBCA.FM', 'mu-CCCAB.FM', 'mu-CCCBA.FM']
ternarychiFM   = ['chi-AABC.FM', 'chi-AACB.FM', 'chi-ABAC.FM', 'chi-ABBC.FM', 'chi-ABCA.FM', 'chi-ABCB.FM',
                  'chi-ABCC.FM', 'chi-ACAB.FM', 'chi-ACBA.FM', 'chi-ACBB.FM', 'chi-ACBC.FM', 'chi-ACCB.FM', 
                  'chi-BAAC.FM', 'chi-BABC.FM', 'chi-BACA.FM', 'chi-BACB.FM', 'chi-BACC.FM', 'chi-BBAC.FM', 
                  'chi-BBCA.FM', 'chi-BCAA.FM', 'chi-BCAB.FM', 'chi-BCAC.FM', 'chi-BCBA.FM', 'chi-BCCA.FM', 
                  'chi-CAAB.FM', 'chi-CABA.FM', 'chi-CABB.FM', 'chi-CABC.FM', 'chi-CACB.FM', 'chi-CBAA.FM', 
                  'chi-CBAB.FM', 'chi-CBAC.FM', 'chi-CBBA.FM', 'chi-CBCA.FM', 'chi-CCAB.FM', 'chi-CCBA.FM']
list_ternary_mag = ternaryA15FM+ternaryC14FM+ternaryC15FM+ternaryC36FM+ternarysigmaFM+ternarymuFM+ternarychiFM

# %%
ternaryA15   = ['A15-AAAAAABC', 'A15-AAAAABCC', 'A15-AAAAACBB', 'A15-AAAABACC',
                'A15-AAAACABB', 'A15-AAABAACC', 'A15-AAACAABB', 'A15-AABAAACC',
                'A15-AACAAABB', 'A15-ABAAAACC', 'A15-ACAAAABB', 'A15-BAAAAACC',
                'A15-CAAAAABB']
ternaryC14   = ['C14-ABC', 'C14-ACB', 'C14-BAC', 'C14-BCA', 'C14-CAB', 
                'C14-CBA']
ternaryC15   = []
ternaryC36   = ['C36-AAABC', 'C36-AAACB', 'C36-AABAC', 'C36-AABBC', 'C36-AABCA', 'C36-AABCB',
                'C36-AABCC', 'C36-AACAB', 'C36-AACBA', 'C36-AACBB', 'C36-AACBC', 'C36-AACCB',
                'C36-ABAAC', 'C36-ABABC', 'C36-ABACA', 'C36-ABACB', 'C36-ABACC', 'C36-ABBAC',
                'C36-ABBBC', 'C36-ABBCA', 'C36-ABBCB', 'C36-ABBCC', 'C36-ABCAA', 'C36-ABCAB',
                'C36-ABCAC', 'C36-ABCBA', 'C36-ABCBB', 'C36-ABCBC', 'C36-ABCCA', 'C36-ABCCB',
                'C36-ABCCC', 'C36-ACAAB', 'C36-ACABA', 'C36-ACABB', 'C36-ACABC', 'C36-ACACB',
                'C36-ACBAA', 'C36-ACBAB', 'C36-ACBAC', 'C36-ACBBA', 'C36-ACBBB', 'C36-ACBBC',
                'C36-ACBCA', 'C36-ACBCB', 'C36-ACBCC', 'C36-ACCAB', 'C36-ACCBA', 'C36-ACCBB',
                'C36-ACCBC', 'C36-ACCCB', 'C36-BAAAC', 'C36-BAABC', 'C36-BAACA', 'C36-BAACB',
                'C36-BAACC', 'C36-BABAC', 'C36-BABBC', 'C36-BABCA', 'C36-BABCB', 'C36-BABCC',
                'C36-BACAA', 'C36-BACAB', 'C36-BACAC', 'C36-BACBA', 'C36-BACBB', 'C36-BACBC',
                'C36-BACCA', 'C36-BACCB', 'C36-BACCC', 'C36-BBAAC', 'C36-BBABC', 'C36-BBACA',
                'C36-BBACB', 'C36-BBACC', 'C36-BBBAC', 'C36-BBBCA', 'C36-BBCAA', 'C36-BBCAB',
                'C36-BBCAC', 'C36-BBCBA', 'C36-BBCCA', 'C36-BCAAA', 'C36-BCAAB', 'C36-BCAAC',
                'C36-BCABA', 'C36-BCABB', 'C36-BCABC', 'C36-BCACA', 'C36-BCACB', 'C36-BCACC',
                'C36-BCBAA', 'C36-BCBAB', 'C36-BCBAC', 'C36-BCBBA', 'C36-BCBCA', 'C36-BCCAA',
                'C36-BCCAB', 'C36-BCCAC', 'C36-BCCBA', 'C36-BCCCA', 'C36-CAAAB', 'C36-CAABA',
                'C36-CAABB', 'C36-CAABC', 'C36-CAACB', 'C36-CABAA', 'C36-CABAB', 'C36-CABAC',
                'C36-CABBA', 'C36-CABBB', 'C36-CABBC', 'C36-CABCA', 'C36-CABCB', 'C36-CABCC',
                'C36-CACAB', 'C36-CACBA', 'C36-CACBB', 'C36-CACBC', 'C36-CACCB', 'C36-CBAAA',
                'C36-CBAAB', 'C36-CBAAC', 'C36-CBABA', 'C36-CBABB', 'C36-CBABC', 'C36-CBACA',
                'C36-CBACB', 'C36-CBACC', 'C36-CBBAA', 'C36-CBBAB', 'C36-CBBAC', 'C36-CBBBA',
                'C36-CBBCA', 'C36-CBCAA', 'C36-CBCAB', 'C36-CBCAC', 'C36-CBCBA', 'C36-CBCCA',
                'C36-CCAAB', 'C36-CCABA', 'C36-CCABB', 'C36-CCABC', 'C36-CCACB', 'C36-CCBAA',
                'C36-CCBAB', 'C36-CCBAC', 'C36-CCBBA', 'C36-CCBCA', 'C36-CCCAB', 'C36-CCCBA']
ternarysigma = ['sigma-AAABC', 'sigma-AAACB', 'sigma-AABAC', 'sigma-AABBC', 'sigma-AABCA',
                'sigma-AABCB', 'sigma-AABCC', 'sigma-AACAB', 'sigma-AACBA', 'sigma-AACBB',
                'sigma-AACBC', 'sigma-AACCB', 'sigma-ABAAC', 'sigma-ABABC', 'sigma-ABACA',
                'sigma-ABACB', 'sigma-ABACC', 'sigma-ABBAC', 'sigma-ABBBC', 'sigma-ABBCA',
                'sigma-ABBCB', 'sigma-ABBCC', 'sigma-ABCAA', 'sigma-ABCAB', 'sigma-ABCAC',
                'sigma-ABCBA', 'sigma-ABCBB', 'sigma-ABCBC', 'sigma-ABCCA', 'sigma-ABCCB',
                'sigma-ABCCC', 'sigma-ACAAB', 'sigma-ACABA', 'sigma-ACABB', 'sigma-ACABC',
                'sigma-ACACB', 'sigma-ACBAA', 'sigma-ACBAB', 'sigma-ACBAC', 'sigma-ACBBA',
                'sigma-ACBBB', 'sigma-ACBBC', 'sigma-ACBCA', 'sigma-ACBCB', 'sigma-ACBCC',
                'sigma-ACCAB', 'sigma-ACCBA', 'sigma-ACCBB', 'sigma-ACCBC', 'sigma-ACCCB',
                'sigma-BAAAC', 'sigma-BAABC', 'sigma-BAACA', 'sigma-BAACB', 'sigma-BAACC',
                'sigma-BABAC', 'sigma-BABBC', 'sigma-BABCA', 'sigma-BABCB', 'sigma-BABCC',
                'sigma-BACAA', 'sigma-BACAB', 'sigma-BACAC', 'sigma-BACBA', 'sigma-BACBB',
                'sigma-BACBC', 'sigma-BACCA', 'sigma-BACCB', 'sigma-BACCC', 'sigma-BBAAC',
                'sigma-BBABC', 'sigma-BBACA', 'sigma-BBACB', 'sigma-BBACC', 'sigma-BBBAC',
                'sigma-BBBCA', 'sigma-BBCAA', 'sigma-BBCAB', 'sigma-BBCAC', 'sigma-BBCBA',
                'sigma-BBCCA', 'sigma-BCAAA', 'sigma-BCAAB', 'sigma-BCAAC', 'sigma-BCABA',
                'sigma-BCABB', 'sigma-BCABC', 'sigma-BCACA', 'sigma-BCACB', 'sigma-BCACC',
                'sigma-BCBAA', 'sigma-BCBAB', 'sigma-BCBAC', 'sigma-BCBBA', 'sigma-BCBCA',
                'sigma-BCCAA', 'sigma-BCCAB', 'sigma-BCCAC', 'sigma-BCCBA', 'sigma-BCCCA',
                'sigma-CAAAB', 'sigma-CAABA', 'sigma-CAABB', 'sigma-CAABC', 'sigma-CAACB',
                'sigma-CABAA', 'sigma-CABAB', 'sigma-CABAC', 'sigma-CABBA', 'sigma-CABBB',
                'sigma-CABBC', 'sigma-CABCA', 'sigma-CABCB', 'sigma-CABCC', 'sigma-CACAB',
                'sigma-CACBA', 'sigma-CACBB', 'sigma-CACBC', 'sigma-CACCB', 'sigma-CBAAA',
                'sigma-CBAAB', 'sigma-CBAAC', 'sigma-CBABA', 'sigma-CBABB', 'sigma-CBABC',
                'sigma-CBACA', 'sigma-CBACB', 'sigma-CBACC', 'sigma-CBBAA', 'sigma-CBBAB',
                'sigma-CBBAC', 'sigma-CBBBA', 'sigma-CBBCA', 'sigma-CBCAA', 'sigma-CBCAB',
                'sigma-CBCAC', 'sigma-CBCBA', 'sigma-CBCCA', 'sigma-CCAAB', 'sigma-CCABA',
                'sigma-CCABB', 'sigma-CCABC', 'sigma-CCACB', 'sigma-CCBAA', 'sigma-CCBAB',
                'sigma-CCBAC', 'sigma-CCBBA', 'sigma-CCBCA', 'sigma-CCCAB', 'sigma-CCCBA']
ternarymu    = ['mu-AAABC', 'mu-AAACB', 'mu-AABAC', 'mu-AABBC', 'mu-AABCA', 'mu-AABCB',
                'mu-AABCC', 'mu-AACAB', 'mu-AACBA', 'mu-AACBB', 'mu-AACBC', 'mu-AACCB',
                'mu-ABAAC', 'mu-ABABC', 'mu-ABACA', 'mu-ABACB', 'mu-ABACC', 'mu-ABBAC',
                'mu-ABBBC', 'mu-ABBCA', 'mu-ABBCB', 'mu-ABBCC', 'mu-ABCAA', 'mu-ABCAB',
                'mu-ABCAC', 'mu-ABCBA', 'mu-ABCBB', 'mu-ABCBC', 'mu-ABCCA', 'mu-ABCCB',
                'mu-ABCCC', 'mu-ACAAB', 'mu-ACABA', 'mu-ACABB', 'mu-ACABC', 'mu-ACACB',
                'mu-ACBAA', 'mu-ACBAB', 'mu-ACBAC', 'mu-ACBBA', 'mu-ACBBB', 'mu-ACBBC',
                'mu-ACBCA', 'mu-ACBCB', 'mu-ACBCC', 'mu-ACCAB', 'mu-ACCBA', 'mu-ACCBB',
                'mu-ACCBC', 'mu-ACCCB', 'mu-BAAAC', 'mu-BAABC', 'mu-BAACA', 'mu-BAACB',
                'mu-BAACC', 'mu-BABAC', 'mu-BABBC', 'mu-BABCA', 'mu-BABCB', 'mu-BABCC',
                'mu-BACAA', 'mu-BACAB', 'mu-BACAC', 'mu-BACBA', 'mu-BACBB', 'mu-BACBC',
                'mu-BACCA', 'mu-BACCB', 'mu-BACCC', 'mu-BBAAC', 'mu-BBABC', 'mu-BBACA',
                'mu-BBACB', 'mu-BBACC', 'mu-BBBAC', 'mu-BBBCA', 'mu-BBCAA', 'mu-BBCAB',
                'mu-BBCAC', 'mu-BBCBA', 'mu-BBCCA', 'mu-BCAAA', 'mu-BCAAB', 'mu-BCAAC',
                'mu-BCABA', 'mu-BCABB', 'mu-BCABC', 'mu-BCACA', 'mu-BCACB', 'mu-BCACC',
                'mu-BCBAA', 'mu-BCBAB', 'mu-BCBAC', 'mu-BCBBA', 'mu-BCBCA', 'mu-BCCAA',
                'mu-BCCAB', 'mu-BCCAC', 'mu-BCCBA', 'mu-BCCCA', 'mu-CAAAB', 'mu-CAABA',
                'mu-CAABB', 'mu-CAABC', 'mu-CAACB', 'mu-CABAA', 'mu-CABAB', 'mu-CABAC',
                'mu-CABBA', 'mu-CABBB', 'mu-CABBC', 'mu-CABCA', 'mu-CABCB', 'mu-CABCC',
                'mu-CACAB', 'mu-CACBA', 'mu-CACBB', 'mu-CACBC', 'mu-CACCB', 'mu-CBAAA',
                'mu-CBAAB', 'mu-CBAAC', 'mu-CBABA', 'mu-CBABB', 'mu-CBABC', 'mu-CBACA',
                'mu-CBACB', 'mu-CBACC', 'mu-CBBAA', 'mu-CBBAB', 'mu-CBBAC', 'mu-CBBBA',
                'mu-CBBCA', 'mu-CBCAA', 'mu-CBCAB', 'mu-CBCAC', 'mu-CBCBA', 'mu-CBCCA',
                'mu-CCAAB', 'mu-CCABA', 'mu-CCABB', 'mu-CCABC', 'mu-CCACB', 'mu-CCBAA',
                'mu-CCBAB', 'mu-CCBAC', 'mu-CCBBA', 'mu-CCBCA', 'mu-CCCAB', 'mu-CCCBA']
ternarychi   = ['chi-AABC', 'chi-AACB', 'chi-ABAC', 'chi-ABBC', 'chi-ABCA', 'chi-ABCB',
                'chi-ABCC', 'chi-ACAB', 'chi-ACBA', 'chi-ACBB', 'chi-ACBC', 'chi-ACCB', 
                'chi-BAAC', 'chi-BABC', 'chi-BACA', 'chi-BACB', 'chi-BACC', 'chi-BBAC',
                'chi-BBCA', 'chi-BCAA', 'chi-BCAB', 'chi-BCAC', 'chi-BCBA', 'chi-BCCA', 
                'chi-CAAB', 'chi-CABA', 'chi-CABB', 'chi-CABC', 'chi-CACB', 'chi-CBAA', 
                'chi-CBAB', 'chi-CBAC', 'chi-CBBA', 'chi-CBCA', 'chi-CCAB', 'chi-CCBA']
list_ternary_nonmag = ternaryA15+ternaryC14+ternaryC15+ternaryC36+ternarysigma+ternarymu+ternarychi

# %% [markdown]
# # all the briefsummaries around

# %%
allfiles = glob.glob('**/briefsummary.dat', recursive=True)

# %%
alllists = [list_binary_mag, list_binary_nonmag, list_ternary_mag, list_ternary_nonmag]

# %%
totalfounds = 0
for file, caselist in product(allfiles, alllists) :
    searchresult = collect(file, caselist )
    totalfounds += pd.Series(searchresult).str.contains('\+').sum()

# %%
display(Latex('a total of ${}$ finished calculations were found'.format(totalfounds)))
# Out:
# a total of $251$ finished calculations were found

# %%
from BopFoxFeaturizer.brief_summary_parser import StructSummaryParser

# %%
Parser = StructSummaryParser()

# %%
BS = Parser.BriefSummary

# %%
BS[BS['nelem']==1].shape
# Out:
# (73, 20)

# %%
binary_and_ternaries = BS[BS['nelem']==2].shape[0] + BS[BS['nelem']==3].shape[0]

# %%
display(Markdown('the total ammount of **binaries + ternaries** finished are **{}**'.format(binary_and_ternaries)))
# Out:
# the total ammount of **binaries + ternaries** finished are **267**

# %% [markdown]
# # Cr-Co magnetic

# %%
searchresult = collect('Cr_pv-Co_pv-W_sv/briefsummary.dat', list_binary_mag)

# %% [markdown]
# # Cr-Co nonmagnetic

# %%
collect('Cr_pv-Co_pv/briefsummary.dat',list_binary_nonmag)
# Out:
# ['A15-AB  ---------',
#  'A15-BA  ---------',
#  'C14-AAB  ---------',
#  'C14-ABA  ---------',
#  'C14-ABB  ---------',
#  'C14-BAA  ---------',
#  'C14-BAB  ---------',
#  'C14-BBA  ---------',
#  'C15-AB2  ---------',
#  'C15-A2B  ---------',
#  'C36-AAAAB  ---------',
#  'C36-AAABA  ---------',
#  'C36-AAABB  ---------',
#  'C36-AABAA  ---------',
#  'C36-AABAB  ---------',
#  'C36-AABBA  ---------',
#  'C36-AABBB  ---------',
#  'C36-ABAAA  ---------',
#  'C36-ABAAB  ---------',
#  'C36-ABABA  ---------',
#  'C36-ABABB  ---------',
#  'C36-ABBAA  ---------',
#  'C36-ABBAB  ---------',
#  'C36-ABBBA  ---------',
#  'C36-ABBBB  ---------',
#  'C36-BAAAA  ---------',
#  'C36-BAAAB  ---------',
#  'C36-BAABA  ---------',
#  'C36-BAABB  ---------',
#  'C36-BABAA  ---------',
#  'C36-BABAB  ---------',
#  'C36-BABBA  ---------',
#  'C36-BABBB  ---------',
#  'C36-BBAAA  ---------',
#  'C36-BBAAB  ---------',
#  'C36-BBABA  ---------',
#  'C36-BBABB  ---------',
# ...

# %% [markdown]
# # Cr-W magnetic

# %%
collect('Cr_pv-W_sv/briefsummary.dat',list_binary_mag)
# Out:
# ['A15-AB.FM+++++++++',
#  'A15-BA.FM+++++++++',
#  'C14-AAB.FM+++++++++',
#  'C14-ABA.FM+++++++++',
#  'C14-ABB.FM+++++++++',
#  'C14-BAA.FM+++++++++',
#  'C14-BAB.FM  ---------',
#  'C14-BBA.FM+++++++++',
#  'C15-AB2.FM  ---------',
#  'C15-A2B.FM  ---------',
#  'C36-AAAAB.FM+++++++++',
#  'C36-AAABA.FM+++++++++',
#  'C36-AAABB.FM+++++++++',
#  'C36-AABAA.FM+++++++++',
#  'C36-AABAB.FM+++++++++',
#  'C36-AABBA.FM+++++++++',
#  'C36-AABBB.FM+++++++++',
#  'C36-ABAAA.FM+++++++++',
#  'C36-ABAAB.FM+++++++++',
#  'C36-ABABA.FM+++++++++',
#  'C36-ABABB.FM+++++++++',
#  'C36-ABBAA.FM+++++++++',
#  'C36-ABBAB.FM+++++++++',
#  'C36-ABBBA.FM+++++++++',
#  'C36-ABBBB.FM+++++++++',
#  'C36-BAAAA.FM+++++++++',
#  'C36-BAAAB.FM+++++++++',
#  'C36-BAABA.FM+++++++++',
#  'C36-BAABB.FM+++++++++',
#  'C36-BABAA.FM+++++++++',
#  'C36-BABAB.FM+++++++++',
#  'C36-BABBA.FM+++++++++',
#  'C36-BABBB.FM+++++++++',
#  'C36-BBAAA.FM+++++++++',
#  'C36-BBAAB.FM+++++++++',
#  'C36-BBABA.FM+++++++++',
# ...

# %% [markdown]
# # Cr-W nonmagnetic

# %%
collect('Cr_pv-W_sv/briefsummary.dat',list_binary_nonmag)
# Out:
# ['A15-AB  ---------',
#  'A15-BA  ---------',
#  'C14-AAB  ---------',
#  'C14-ABA  ---------',
#  'C14-ABB  ---------',
#  'C14-BAA  ---------',
#  'C14-BAB  ---------',
#  'C14-BBA  ---------',
#  'C15-AB2  ---------',
#  'C15-A2B  ---------',
#  'C36-AAAAB  ---------',
#  'C36-AAABA  ---------',
#  'C36-AAABB  ---------',
#  'C36-AABAA  ---------',
#  'C36-AABAB  ---------',
#  'C36-AABBA  ---------',
#  'C36-AABBB  ---------',
#  'C36-ABAAA  ---------',
#  'C36-ABAAB  ---------',
#  'C36-ABABA  ---------',
#  'C36-ABABB  ---------',
#  'C36-ABBAA  ---------',
#  'C36-ABBAB  ---------',
#  'C36-ABBBA  ---------',
#  'C36-ABBBB  ---------',
#  'C36-BAAAA  ---------',
#  'C36-BAAAB  ---------',
#  'C36-BAABA  ---------',
#  'C36-BAABB  ---------',
#  'C36-BABAA  ---------',
#  'C36-BABAB  ---------',
#  'C36-BABBA  ---------',
#  'C36-BABBB  ---------',
#  'C36-BBAAA  ---------',
#  'C36-BBAAB  ---------',
#  'C36-BBABA  ---------',
#  'C36-BBABB  ---------',
# ...

# %% [markdown]
# # Co-W magnetic

# %%
collect('Co_pv-W_sv/briefsummary.dat',list_binary_mag)
# Out:
# ['A15-AB.FM+++++++++',
#  'A15-BA.FM+++++++++',
#  'C14-AAB.FM+++++++++',
#  'C14-ABA.FM+++++++++',
#  'C14-ABB.FM+++++++++',
#  'C14-BAA.FM+++++++++',
#  'C14-BAB.FM+++++++++',
#  'C14-BBA.FM+++++++++',
#  'C15-AB2.FM  ---------',
#  'C15-A2B.FM  ---------',
#  'C36-AAAAB.FM  ---------',
#  'C36-AAABA.FM+++++++++',
#  'C36-AAABB.FM+++++++++',
#  'C36-AABAA.FM+++++++++',
#  'C36-AABAB.FM  ---------',
#  'C36-AABBA.FM+++++++++',
#  'C36-AABBB.FM  ---------',
#  'C36-ABAAA.FM+++++++++',
#  'C36-ABAAB.FM+++++++++',
#  'C36-ABABA.FM+++++++++',
#  'C36-ABABB.FM  ---------',
#  'C36-ABBAA.FM+++++++++',
#  'C36-ABBAB.FM+++++++++',
#  'C36-ABBBA.FM+++++++++',
#  'C36-ABBBB.FM  ---------',
#  'C36-BAAAA.FM+++++++++',
#  'C36-BAAAB.FM  ---------',
#  'C36-BAABA.FM+++++++++',
#  'C36-BAABB.FM+++++++++',
#  'C36-BABAA.FM+++++++++',
#  'C36-BABAB.FM+++++++++',
#  'C36-BABBA.FM  ---------',
#  'C36-BABBB.FM+++++++++',
#  'C36-BBAAA.FM+++++++++',
#  'C36-BBAAB.FM+++++++++',
# ...

# %% [markdown]
# # Co-W nonmagnetic

# %%
collect('Co_pv-W_sv/briefsummary.dat',list_binary_nonmag)
# Out:
# ['A15-AB  ---------',
#  'A15-BA  ---------',
#  'C14-AAB  ---------',
#  'C14-ABA  ---------',
#  'C14-ABB  ---------',
#  'C14-BAA  ---------',
#  'C14-BAB  ---------',
#  'C14-BBA  ---------',
#  'C15-AB2  ---------',
#  'C15-A2B  ---------',
#  'C36-AAAAB  ---------',
#  'C36-AAABA  ---------',
#  'C36-AAABB  ---------',
#  'C36-AABAA  ---------',
#  'C36-AABAB  ---------',
#  'C36-AABBA  ---------',
#  'C36-AABBB  ---------',
#  'C36-ABAAA  ---------',
#  'C36-ABAAB  ---------',
#  'C36-ABABA  ---------',
#  'C36-ABABB  ---------',
#  'C36-ABBAA  ---------',
#  'C36-ABBAB  ---------',
#  'C36-ABBBA  ---------',
#  'C36-ABBBB  ---------',
#  'C36-BAAAA  ---------',
#  'C36-BAAAB  ---------',
#  'C36-BAABA  ---------',
#  'C36-BAABB  ---------',
#  'C36-BABAA  ---------',
#  'C36-BABAB  ---------',
#  'C36-BABBA  ---------',
#  'C36-BABBB  ---------',
#  'C36-BBAAA  ---------',
#  'C36-BBAAB  ---------',
#  'C36-BBABA  ---------',
#  'C36-BBABB  ---------',
# ...

# %% [markdown]
# # Cr-Co-W magnetic

# %%
collect('Cr_pv-Co_pv-W_sv/briefsummary.dat',list_ternary_mag)
# Out:
# ['A15-AAAAAABC.FM  ---------',
#  'A15-AAAAABCC.FM  ---------',
#  'A15-AAAAACBB.FM  ---------',
#  'A15-AAAABACC.FM  ---------',
#  'A15-AAAACABB.FM  ---------',
#  'A15-AAABAACC.FM  ---------',
#  'A15-AAACAABB.FM  ---------',
#  'A15-AABAAACC.FM  ---------',
#  'A15-AACAAABB.FM  ---------',
#  'A15-ABAAAACC.FM  ---------',
#  'A15-ACAAAABB.FM  ---------',
#  'A15-BAAAAACC.FM  ---------',
#  'A15-CAAAAABB.FM  ---------',
#  'C14-ABC.FM+++++++++',
#  'C14-ACB.FM+++++++++',
#  'C14-BAC.FM+++++++++',
#  'C14-BCA.FM+++++++++',
#  'C14-CAB.FM+++++++++',
#  'C14-CBA.FM+++++++++',
#  'C36-AAABC.FM  ---------',
#  'C36-AAACB.FM  ---------',
#  'C36-AABAC.FM  ---------',
#  'C36-AABBC.FM  ---------',
#  'C36-AABCA.FM  ---------',
#  'C36-AABCB.FM  ---------',
#  'C36-AABCC.FM  ---------',
#  'C36-AACAB.FM  ---------',
#  'C36-AACBA.FM  ---------',
#  'C36-AACBB.FM  ---------',
#  'C36-AACBC.FM  ---------',
#  'C36-AACCB.FM  ---------',
#  'C36-ABAAC.FM  ---------',
# ...

# %% [markdown]
# # Cr-Co-W nonmagnetic

# %%
collect('Cr_pv-Co_pv-W_sv/briefsummary.dat',list_ternary_nonmag)
# Out:
# ['A15-AAAAAABC  ---------',
#  'A15-AAAAABCC  ---------',
#  'A15-AAAAACBB  ---------',
#  'A15-AAAABACC  ---------',
#  'A15-AAAACABB  ---------',
#  'A15-AAABAACC  ---------',
#  'A15-AAACAABB  ---------',
#  'A15-AABAAACC  ---------',
#  'A15-AACAAABB  ---------',
#  'A15-ABAAAACC  ---------',
#  'A15-ACAAAABB  ---------',
#  'A15-BAAAAACC  ---------',
#  'A15-CAAAAABB  ---------',
#  'C14-ABC  ---------',
#  'C14-ACB  ---------',
#  'C14-BAC  ---------',
#  'C14-BCA  ---------',
#  'C14-CAB  ---------',
#  'C14-CBA  ---------',
#  'C36-AAABC  ---------',
#  'C36-AAACB  ---------',
#  'C36-AABAC  ---------',
#  'C36-AABBC  ---------',
#  'C36-AABCA  ---------',
#  'C36-AABCB  ---------',
#  'C36-AABCC  ---------',
#  'C36-AACAB  ---------',
#  'C36-AACBA  ---------',
#  'C36-AACBB  ---------',
#  'C36-AACBC  ---------',
#  'C36-AACCB  ---------',
#  'C36-ABAAC  ---------',
#  'C36-ABABC  ---------',
#  'C36-ABACA  ---------',
#  'C36-ABACB  ---------',
#  'C36-ABACC  ---------',
# ...
